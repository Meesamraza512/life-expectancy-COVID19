# %% [markdown]
# # Project Title:
# ### Data Cleaning for a Real-world Dataset

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Read Dataset

# %%
# Load dataset
file_path = "Life Expectancy Data.csv"
df= pd.read_csv(file_path)
df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
# head
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
# tail
df.tail()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2933  Zimbabwe  2004  Developing              44.3            723.0
# 2934  Zimbabwe  2003  Developing              44.5            715.0
# 2935  Zimbabwe  2002  Developing              44.8             73.0
# 2936  Zimbabwe  2001  Developing              45.3            686.0
# 2937  Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2933             27     4.36                     0.0         68.0        31
# 2934             26     4.06                     0.0          7.0       998
# 2935             25     4.43                     0.0         73.0       304
# 2936             25     1.72                     0.0         76.0       529
# 2937             24     1.68                     0.0         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# ...

# %% [markdown]
# # Sanity Check of Data

# %%
# shape
df.shape
# Out:
# (2938, 22)

# %%
# info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %% [markdown]
# # check missing values

# %%
# check missing values
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %% [markdown]
# # check the duplicate values

# %%
# check the duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
# if duplicate value in dataset
# Removing dutplicaes
df.drop_duplicates(inplace=True)

# %% [markdown]
# # Summary statistics

# %%
# describe
df.describe().T
# Out:
#                                   count          mean           std  \
# Year                             2938.0  2.007519e+03  4.613841e+00
# Life expectancy                  2928.0  6.922493e+01  9.523867e+00
# Adult Mortality                  2928.0  1.647964e+02  1.242921e+02
# infant deaths                    2938.0  3.030395e+01  1.179265e+02
# Alcohol                          2744.0  4.602861e+00  4.052413e+00
# percentage expenditure           2938.0  7.382513e+02  1.987915e+03
# Hepatitis B                      2385.0  8.094046e+01  2.507002e+01
# Measles                          2938.0  2.419592e+03  1.146727e+04
#  BMI                             2904.0  3.832125e+01  2.004403e+01
# under-five deaths                2938.0  4.203574e+01  1.604455e+02
# Polio                            2919.0  8.255019e+01  2.342805e+01
# Total expenditure                2712.0  5.938190e+00  2.498320e+00
# Diphtheria                       2919.0  8.232408e+01  2.371691e+01
# ...

# %% [markdown]
# # Missing Value Treatments

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %% [markdown]
# ### First Method Fill The Missing Value on Numerical Datatype

# %%
df.select_dtypes(include="number").columns
# Out:
# Index(['Year', 'Life expectancy ', 'Adult Mortality', 'infant deaths',
#        'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
#        'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
#        ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
#        ' thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
for i in ['Year', 'Life expectancy ', 'Adult Mortality', 'infant deaths',
       'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
       'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
       ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
       ' thinness 5-9 years', 'Income composition of resources', 'Schooling']:
    df[i].fillna(df[i].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %% [markdown]
# ### Second Method Fill The Missing Value on Numerical Datatype

# %%
from sklearn.impute import KNNImputer
impute=KNNImputer()

# %%
for i in df.select_dtypes(include="number").columns:
    df[i]=impute.fit_transform(df[[i]])

# %%
df.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %% [markdown]
# # Outliers Treatments

# %% [markdown]
# ## Check the Outliers

# %%
for i in df.select_dtypes(include="number").columns:
    sns.boxplot(data=df,y=i)
    plt.show()

# %% [markdown]
# ## Handle the Outliers

# %%
def wisker(col):
    q1,q3=np.percentile(col,[25,75])
    IQR=q3-q1   # Interquartile Range
    
    # Define lower and upper bounds
    lower_bound = q1 - 1.5 * IQR
    upper_bound = q3 + 1.5 * IQR
    return lower_bound,upper_bound

# %%
for i in ['GDP','Life expectancy ', 'Adult Mortality',
       'infant deaths','Alcohol','percentage expenditure', 'Hepatitis B',
       'Measles ', 'under-five deaths ', 'Polio', 'Total expenditure',
       'Diphtheria ', ' HIV/AIDS','Population',
       ' thinness  1-19 years', ' thinness 5-9 years',
       'Income composition of resources', 'Schooling']:
    lower_bound , upper_bound = wisker(df[i])
    df[i]=np.where(df[i] < lower_bound , lower_bound , df[i])
    df[i]=np.where(df[i] > upper_bound , upper_bound , df[i])

# %%
for i in df.select_dtypes(include="number").columns:
    sns.boxplot(data=df,y=i)
    plt.show()

# %% [markdown]
# # Encoding of Data

# %%
# Lable encoding and one hot encoding with pd.get_dummies

# %%
dummy=pd.get_dummies(data=df,columns=["Country","Status"],drop_first=True)

# %%
dummy
# Out:
#         Year  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0     2015.0              65.0            263.0           55.0     0.01
# 1     2014.0              59.9            271.0           55.0     0.01
# 2     2013.0              59.9            268.0           55.0     0.01
# 3     2012.0              59.5            272.0           55.0     0.01
# 4     2011.0              59.2            275.0           55.0     0.01
# ...      ...               ...              ...            ...      ...
# 2933  2004.0              44.6            456.5           27.0     4.36
# 2934  2003.0              44.6            456.5           26.0     4.06
# 2935  2002.0              44.8             73.0           25.0     4.43
# 2936  2001.0              45.3            456.5           25.0     1.72
# 2937  2000.0              46.0            456.5           24.0     1.68
#
#       percentage expenditure  Hepatitis B  Measles    BMI   \
# ...

# %% [markdown]
# # Normalize Numeric Columns

# %%
from sklearn.preprocessing import MinMaxScaler

# Normalize Numeric Columns
num_cols = df.select_dtypes(include="number").columns  # Select numeric columns
scaler = MinMaxScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])

# %%
df[num_cols].head()
# Out:
#        Year  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0  1.000000          0.459459         0.575192            1.0      0.0
# 1  0.933333          0.344595         0.592755            1.0      0.0
# 2  0.866667          0.344595         0.586169            1.0      0.0
# 3  0.800000          0.335586         0.594951            1.0      0.0
# 4  0.733333          0.328829         0.601537            1.0      0.0
#
#    percentage expenditure  Hepatitis B  Measles       BMI   \
# 0                0.064988     0.105263  1.000000  0.209733
# 1                0.067034     0.026316  0.546287  0.203940
# 2                0.066757     0.078947  0.477446  0.198146
# 3                0.071283     0.157895  1.000000  0.192352
# 4                0.006471     0.184211  1.000000  0.187717
#
#    under-five deaths      Polio  Total expenditure  Diphtheria    HIV/AIDS  \
# 0                 1.0  0.000000           0.683333     0.313131        0.0
# ...

# %% [markdown]
# # Save the cleaned and normalized dataset

# %%
# Save the cleaned and normalized dataset
df.to_csv("Cleaned_Life_Expectancy.csv", index=False)

# %% [markdown]
# # Display cleaned data

# %%
# Display cleaned data
print(" Data Cleaning & Normalization Done!")
df.head()
# Out:
#  Data Cleaning & Normalization Done!
#        Country      Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  1.000000  Developing          0.459459         0.575192
# 1  Afghanistan  0.933333  Developing          0.344595         0.592755
# 2  Afghanistan  0.866667  Developing          0.344595         0.586169
# 3  Afghanistan  0.800000  Developing          0.335586         0.594951
# 4  Afghanistan  0.733333  Developing          0.328829         0.601537
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0            1.0      0.0                0.064988     0.105263  1.000000  ...
# 1            1.0      0.0                0.067034     0.026316  0.546287  ...
# 2            1.0      0.0                0.066757     0.078947  0.477446  ...
# 3            1.0      0.0                0.071283     0.157895  1.000000  ...
# 4            1.0      0.0                0.006471     0.184211  1.000000  ...
#
# ...
